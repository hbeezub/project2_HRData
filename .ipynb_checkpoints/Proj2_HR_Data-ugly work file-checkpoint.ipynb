# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('HR_comma_sep.csv')

# %%
data.shape
# Out:
# (14999, 10)

# %%
data.head(20)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# 5                 0.41             0.50               2                   153
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 8                 0.89             1.00               5                   224
# 9                 0.42             0.53               2                   142
# 10                0.45             0.54               2                   135
# 11                0.11             0.81               6                   305
# 12                0.84             0.92               4                   234
# 13                0.41             0.55               2                   148
# 14                0.36             0.56               2                   137
# 15                0.38             0.54               2                   143
# 16                0.45             0.47               2                   160
# 17                0.78             0.99               4                   255
# 18                0.45             0.51               2                   160
# 19                0.76             0.89               5                   262
#
#     time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                    3              0     1                      0  sales
# 1                    6              0     1                      0  sales
# 2                    4              0     1                      0  sales
# 3                    5              0     1                      0  sales
# 4                    3              0     1                      0  sales
# 5                    3              0     1                      0  sales
# 6                    4              0     1                      0  sales
# 7                    5              0     1                      0  sales
# 8                    5              0     1                      0  sales
# 9                    3              0     1                      0  sales
# 10                   3              0     1                      0  sales
# 11                   4              0     1                      0  sales
# 12                   5              0     1                      0  sales
# 13                   3              0     1                      0  sales
# 14                   3              0     1                      0  sales
# 15                   3              0     1                      0  sales
# 16                   3              0     1                      0  sales
# 17                   6              0     1                      0  sales
# 18                   3              1     1                      1  sales
# 19                   5              0     1                      0  sales
#
#     salary
# 0      low
# 1   medium
# 2   medium
# 3      low
# 4      low
# 5      low
# 6      low
# 7      low
# 8      low
# 9      low
# 10     low
# 11     low
# 12     low
# 13     low
# 14     low
# 15     low
# 16     low
# 17     low
# 18     low
# 19     low

# %%
data.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# 14994                      0  support    low
# 14995                      0  support    low
# 14996                      0  support    low
# 14997                      0  support    low
# 14998                      0  support    low

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# sales                    False
# salary                   False
# dtype: bool

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df_hr1=data.drop(['number_project', 'Work_accident','average_montly_hours','Work_accident','sales'], axis=1)

# %%
quit = df_hr1['left'].value_counts()
print(quit)
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_axes((0,0,.5,1))
ax.set_title('Distribution of employees that leave or stay ie: Turnover')
labels = ['stayed', 'quit']
sizes = [11428, 3571]
colors = ['gold', 'darkgoldenrod']
plt.pie(sizes, labels=labels,colors = colors, autopct = '%1.0f%%',startangle=90, radius=1.5)
plt.axis("equal") #make Pie appear round & not oval
plt.show()

# %%
df_hr1.hist('satisfaction_level')
plt.xlabel('Satisfaction Level')
plt.ylabel('Number of Employees')
plt.title('Distribution of Satisfaction Levels')
plt.show()

# %%
not_employed = df_hr1[df_hr1['left']==1]
still_employed = df_hr1[df_hr1['left']==0]

# %%
# satisfaction level responses into 5 groups

n_ext_satis= not_employed[not_employed.satisfaction_level > .91]
n_very_satis = not_employed[(not_employed.satisfaction_level > .81) & (not_employed.satisfaction_level <= .91)]
n_satis = not_employed[(not_employed.satisfaction_level > .71) & (not_employed.satisfaction_level <= .81)]
n_dis = not_employed[(not_employed.satisfaction_level > .61) & (not_employed.satisfaction_level <= .71)]
n_very_dis = not_employed[not_employed.satisfaction_level <= .61]

# %%
#ne_ext_satis = n_ext_satis.value_counts()
#new = not_employed.value_counts(n_ext_satis)
#new = value_counts(n_ext_satis)
#new = count(n_ext_satis)
#not_employed[not_employed.satisfaction_level > .91].value_counts()
#new = pd.value_counts(n_ext_satis.values)
#CountStatus = pd.value_counts(not_employed[not_employed.satisfaction_level > .91].values, sort=True)
#works#new = pd.value_counts(df_hr1['left'].values, sort=True)
#new = pd.value_counts(n_ext_satis)
count_n_ext_satis=n_ext_satis.count()
count_n_very_satis=n_very_satis.count()
count_n_satis=n_satis.count()
count_n_dis=n_dis.count()
count_n_very_dis=n_very_dis.count()
print(count_n_ext_satis, count_n_very_satis, count_n_satis,count_n_dis, count_n_very_dis)
# Out:
# (satisfaction_level       20
# last_evaluation          20
# time_spend_company       20
# left                     20
# promotion_last_5years    20
# salary                   20
# dtype: int64, satisfaction_level       478
# last_evaluation          478
# time_spend_company       478
# left                     478
# promotion_last_5years    478
# salary                   478
# dtype: int64, satisfaction_level       431
# last_evaluation          431
# time_spend_company       431
# left                     431
# promotion_last_5years    431
# salary                   431
# dtype: int64, satisfaction_level       36
# last_evaluation          36
# time_spend_company       36
# left                     36
# promotion_last_5years    36
# salary                   36
# dtype: int64, satisfaction_level       2606
# last_evaluation          2606
# time_spend_company       2606
# left                     2606
# promotion_last_5years    2606
# salary                   2606
# dtype: int64)

# %%
objects = ('Extremely Satisfied', 'Very Satisfied',' Satisfied' ,'Dissatisfied','Very Dissatisfied')
y_pos = np.arange(len(objects))
performance = [20,478,431,36,2606]
 
plt.bar(y_pos, performance, align='center', alpha=0.5,  color='g')
plt.xticks(y_pos, objects, rotation='70')
plt.ylabel('number of employees')
plt.title('Satisfaction levels of Employees that left')
 
plt.show()

# %%
s_ext_satis= still_employed[still_employed.satisfaction_level > .91]
s_very_satis = still_employed[(still_employed.satisfaction_level > .81) & (still_employed.satisfaction_level <= .91)]
s_satis = still_employed[(still_employed.satisfaction_level > .71) & (still_employed.satisfaction_level <= .81)]
s_dis = still_employed[(still_employed.satisfaction_level > .61) & (still_employed.satisfaction_level <= .71)]
s_very_dis = still_employed[still_employed.satisfaction_level <= .61]

# %%
count_s_ext_satis=s_ext_satis.count()
count_s_very_satis=s_very_satis.count()
count_s_satis=s_satis.count()
count_s_dis=s_dis.count()
count_s_very_dis=s_very_dis.count()
print(count_s_ext_satis, count_s_very_satis, count_s_satis,count_s_dis, count_s_very_dis)
# Out:
# (satisfaction_level       1540
# last_evaluation          1540
# time_spend_company       1540
# left                     1540
# promotion_last_5years    1540
# salary                   1540
# dtype: int64, satisfaction_level       1744
# last_evaluation          1744
# time_spend_company       1744
# left                     1744
# promotion_last_5years    1744
# salary                   1744
# dtype: int64, satisfaction_level       1914
# last_evaluation          1914
# time_spend_company       1914
# left                     1914
# promotion_last_5years    1914
# salary                   1914
# dtype: int64, satisfaction_level       1899
# last_evaluation          1899
# time_spend_company       1899
# left                     1899
# promotion_last_5years    1899
# salary                   1899
# dtype: int64, satisfaction_level       4331
# last_evaluation          4331
# time_spend_company       4331
# left                     4331
# promotion_last_5years    4331
# salary                   4331
# dtype: int64)

# %%
objects = ('Extremely Satisfied', 'Very Satisfied',' Satisfied' ,'Dissatisfied','Very Dissatisfied')
y_pos = np.arange(len(objects))
performance = [1540,1744,1914,1899,4331]
 
plt.bar(y_pos, performance, align='center', alpha=0.5,  color='b')
plt.xticks(y_pos, objects, rotation='70')
plt.ylabel('number of employees')
plt.title('Satisfaction levels of Employees Still at Company')
 
plt.show()

# %%
objects = ('Extremely Satisfied', 'Very Satisfied',' Satisfied' ,'Dissatisfied','Very Dissatisfied')
y_pos = np.arange(len(objects))
s_performance = [1540,1744,1914,1899,4331]
n_performance = [20,478,431,36,2606]

fig, ax = plt.subplots()
index = np.arange(5)
bar_width = 0.35
 
rects1 = plt.bar(index, s_performance, 
                 color='b',
                 label='still employed')
 
rects2 = plt.bar(index+ bar_width, n_performance,
                 color='g',
                 label='left company')
 
plt.bar(y_pos, s_performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation='70')
plt.ylabel('number of employees')
plt.xlabel('Person')
plt.title('Satisfaction levels of Employees Still at Company')
plt.legend()

plt.show()

# %%
#line 21

df_hr1.plot(kind='scatter',x='satisfaction_level',y='last_evaluation', label='Job Satisfaction vs Performance Appraisal', color='orchid', figsize=(20, 10)) 
#plt.figure(figsize=(20,16))
#fig, ax = plt.subplots(figsize=(20, 10))
plt.show()

# %%
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-51-699dd2937a4e> in <module>()
#       3 df_hr1.plot(x, y)
#       4
# ----> 5 df_hr1.plt.xlabel('satisfaction_level')
#       6 df_hr1.plt.ylabel('last_evaluation')
#       7 df_hr1.plt.title('Job Satisfaction vs Performance Appraisal')
#
# C:\Users\hbeezub\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %%
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-44-154600ef802b> in <module>()
#       1 df_hr1.plot(x="satisfaction_level", y="last_evaluation")
# ----> 2 df_hr1.plt.xlabel ('satisfaction_level')
#       3 df_hr1.plt.ylabel ('last_evaluation')
#       4 plt.title('Job Satisfaction vs Performance Appraisal')
#       5 plt.show()
#
# C:\Users\hbeezub\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'
